# %% [markdown]
# # Definition Phrasing

# %% [markdown]
# ## 0. Requirements

# %%
import pandas as pd
from ast import literal_eval
from collections import Counter
import numpy as np

# %% [markdown]
# ## 1. Create/ Load Definitiontexts
#
# Todo:
# - phrase definitions for each main concept
# -

# %%
compounds = pd.read_csv("../output/compounds_full.csv")
#compounds = pd.read_csv("../output/test_compounds.csv")

# %%
compounds = compounds[["original", "lemma", "genus", "compound_forms", 
                      "related_words", "hypernyms", "en_hypernyms", "concept",
                      "definition", "similar_words", "PERS_pro", "PERS_con", 
                       "ORG_pro", "ORG_con", "manual_sentiment", "tf_pro", "tf_con",
                       "tfidf_pro", "tfidf_con"]]

# %%
compounds['compound_forms'] = compounds.compound_forms.apply(lambda x: literal_eval(str(x)))
compounds['related_words'] = compounds.related_words.apply(lambda x: literal_eval(str(x)))
compounds['hypernyms'] = compounds.hypernyms.apply(lambda x: literal_eval(str(x)))
compounds['en_hypernyms'] = compounds.en_hypernyms.apply(lambda x: literal_eval(str(x)) if(str(x) != 'nan') else x)
compounds['definition'] = compounds.definition.apply(lambda x: literal_eval(str(x)))
compounds['PERS_pro'] = compounds.PERS_pro.apply(lambda x: literal_eval(str(x)) if(str(x) != 'nan') else x)
compounds['PERS_con'] = compounds.PERS_con.apply(lambda x: literal_eval(str(x)) if(str(x) != 'nan') else x)
compounds['ORG_pro'] = compounds.ORG_pro.apply(lambda x: literal_eval(str(x)) if(str(x) != 'nan') else x)
compounds['ORG_con'] = compounds.ORG_con.apply(lambda x: literal_eval(str(x)) if(str(x) != 'nan') else x)
compounds['similar_words'] = compounds.similar_words.apply(lambda x: literal_eval(str(x)) if(str(x) != 'nan') else x)

# %%
compounds.PERS_pro = compounds.PERS_pro.apply(lambda x: Counter(x) if(str(x) != 'nan') else x)
compounds.PERS_con = compounds.PERS_con.apply(lambda x: Counter(x) if(str(x) != 'nan') else x)
compounds.ORG_pro = compounds.ORG_pro.apply(lambda x: Counter(x) if(str(x) != 'nan') else x)
compounds.ORG_con = compounds.ORG_con.apply(lambda x: Counter(x) if(str(x) != 'nan') else x)

# %%
for el in compounds.PERS_pro[2].most_common(3):
    print(el[0])
# Out:
# Greta Thunberg
# Vanessa Nakate
# Mitzi Jonelle Tan

# %% [markdown]
# ## 2. Create Placeholders

# %%
persons_text = """Der Begriff {COMPOUND} bezeichnet eine/n {DEFINITION} im Bezug auf den Klimawandel. 
Der Begriff wird in unserem Korpus {CON_FREQ} Mal von den Klimaskeptikern und {PRO_FREQ} Mal von den Klimaaktivisten verwendet
 und ist {SENTIMENT} konnotiert. Personen, die im Zusammenhang mit dem Begriff erwähnt werden sind 
 {CON_PERS1} und {CON_PERS2} (Con Corpus) und {PRO_PERS1} und {PRO_PERS2} (Pro Corpus). 
 Außerdem werden im Kontext von {COMPOUND} folgende Organisationen genannt: {CON_ORG1} und {CON_ORG2} (C2022), sowie {PRO_ORG1} und {PRO_ORG2} (P2022).

Siehe auch: {SIMILAR_WORDS}"""

# %% [markdown]
# ## 3. Fill Placeholders

# %%
print ("Welcome to {name}{num} Tutorials".format(name="Guru", num="99"))
# Out:
# Welcome to Guru99 Tutorials

# %%
#print(persons_text.format(COMPOUND="Klimaleugner", DEFINITION="XXX", CON_FREQ="123",
 #                        PRO_FREQ ="456", SENTIMENT="negative", 
  #                       CON_PERS = "Greta", PRO_PERS="Rahmstorf",
   #                      CON_ORG = "EIKE", PRO_ORG = "FFF",
    #                     SIMILAR_WORDS="Klimaleugnung"))

# %%
#compounds[compounds.original == compound].concept[0]

#idx = compounds.index[compounds['original'] == "klimaleugner"][0]
#compounds['concept'].iloc[idx]

# %%
#def fill_persons(df):
    
for word in compounds.original[:5]:
    #print(compound)
    idx = compounds.index[compounds['original'] == word][0]
    
    if compounds['concept'].iloc[idx] == "person":
        #print(compound)
        
        
        # retrieve according information
        compound = word.capitalize()
        con_freq = compounds['tf_con'].iloc[idx]
        pro_freq = compounds['tf_pro'].iloc[idx]
        sentiment = compounds['manual_sentiment'].iloc[idx]
        similar_words = compounds['similar_words'].iloc[idx]
        
        try:
            definition = compounds['definition'].iloc[idx][0] # try [0] for definition
        except:
            definition = " "
            
        
        # retrieve number of persons. if 0 then do nothing
        
        # if we have at least one person in PERS_con
        if len(compounds['PERS_con'].iloc[idx]) > 0:
            try:
                con_pers = compounds['PERS_con'].iloc[idx].most_common(2)
            except:
                con_pers = compounds['PERS_con'].iloc[idx].most_common(1)[0]
                
        else:
            con_pers = " " 
            
        # if we have at least one person in PERS_con
        if len(compounds['PERS_pro'].iloc[idx]) > 0:
            try:
                pro_pers = compounds['PERS_pro'].iloc[idx].most_common(2)
            except:
                pro_pers = compounds['PERS_pro'].iloc[idx].most_common(1)[0]
                
        else:
            con_pers = " " 
            
        if len(compounds['ORG_con'].iloc[idx]) > 0:
            try:
                con_org = compounds['ORG_con'].iloc[idx].most_common(2)
            except:
                con_org = compounds['ORG_con'].iloc[idx].most_common(1)[0]
                
        else:
            con_org = " " 
            
        # if we have at least one person in PERS_con
        if len(compounds['ORG_pro'].iloc[idx]) > 0:
            try:
                pro_org = compounds['ORG_pro'].iloc[idx].most_common(2)
            except:
                pro_org = compounds['ORG_pro'].iloc[idx].most_common(1)[0]
                
        else:
            pro_org = " "  
            
            
        
            
        
        con_pers1 = [el[0] for el in compounds['PERS_con'].iloc[idx].most_common(2)][0]
        con_pers2 = [el[0] for el in compounds['PERS_con'].iloc[idx].most_common(2)][1]
        pro_pers1 = [el[0] for el in compounds['PERS_pro'].iloc[idx].most_common(2)][0]
        pro_pers2 = [el[0] for el in compounds['PERS_pro'].iloc[idx].most_common(2)][1]

        con_org1 = [el[0] for el in compounds['ORG_con'].iloc[idx].most_common(2)][0]
        con_org2 = [el[0] for el in compounds['ORG_con'].iloc[idx].most_common(2)][1]
        pro_org1 = [el[0] for el in compounds['ORG_pro'].iloc[idx].most_common(2)][0]
        pro_org2 = [el[0] for el in compounds['ORG_pro'].iloc[idx].most_common(2)][1]
            
        con_freq = compounds['tf_con'].iloc[idx]
        pro_freq = compounds['tf_pro'].iloc[idx]
        sentiment = compounds['manual_sentiment'].iloc[idx]
        
        
        similar_words = compounds['similar_words'].iloc[idx]
        
        full_definition = persons_text.format(COMPOUND= compound, DEFINITION= definition, CON_FREQ= con_freq,
                         PRO_FREQ = pro_freq, SENTIMENT= sentiment, CON_PERS1 = con_pers1, CON_PERS2 = con_pers2,
                         PRO_PERS1 = pro_pers1, PRO_PERS2 = pro_pers2, CON_ORG1 = con_org1, CON_ORG2 = con_org2, 
                         PRO_ORG1 = pro_org1, PRO_ORG2 = pro_org2, SIMILAR_WORDS= similar_words)
        
        print(full_definition)
        print("_"*50)
                
        # save to column "full_definition"
# Out:
# Der Begriff Klimaaktivist bezeichnet eine/n ein militanter Reformer im Bezug auf den Klimawandel.
# Der Begriff wird in unserem Korpus 66 Mal von den Klimaskeptikern und 61 Mal von den Klimaaktivisten verwendet
#  und ist positive konnotiert. Personen, die im Zusammenhang mit dem Begriff erwähnt werden sind
#  Greta Thunberg und Bill McKibben (Con Corpus) und Greta Thunberg und Vanessa Nakate (Pro Corpus).
#  Außerdem werden im Kontext von Klimaaktivist folgende Organisationen genannt: EIKE und IPCC (C2022), sowie FFF und EU (P2022).
#
# Siehe auch: ['demagoge', 'macher', 'aktivist', 'aktivismus']
# __________________________________________________
# Der Begriff Klimaaktivistin bezeichnet eine/n   im Bezug auf den Klimawandel.
# Der Begriff wird in unserem Korpus 9 Mal von den Klimaskeptikern und 24 Mal von den Klimaaktivisten verwendet
#  und ist positive konnotiert. Personen, die im Zusammenhang mit dem Begriff erwähnt werden sind
#  Greta Thunberg und Naomi Seibt (Con Corpus) und Greta Thunberg und Howey Ou (Pro Corpus).
#  Außerdem werden im Kontext von Klimaaktivistin folgende Organisationen genannt: New York Post und EIKE (C2022), sowie FFF und EU (P2022).
#
# Siehe auch: ['aktivistin', 'aktivist']
# __________________________________________________

# %%
# these words should not be in PERSON but in ABSTRACTION!!!!


#KLIMAZEUGS, KLIMASCHIFF, KLIMAPRESSE, KLIMAKATAKLYSMUS, KLIMAGEFAHR, KLIMAHOSE, KLIMAFESTUNG, KLIMABLUFF, KLIMABEEINFLUSSUNG

# %%
persons_text = """Der Begriff {COMPOUND} bezeichnet eine/n {DEFINITION} im Bezug auf den Klimawandel. 
Der Begriff wird in unserem Korpus {CON_FREQ} Mal von den Klimaskeptikern und {PRO_FREQ} Mal von den Klimaaktivisten verwendet
 und ist {SENTIMENT} konnotiert. Personen, die im Zusammenhang mit dem Begriff erwähnt werden sind 
 {CON_PERS} (Con Corpus) und {PRO_PERS} (Pro Corpus). 
 Außerdem werden im Kontext von {COMPOUND} folgende Organisationen genannt: {CON_ORG} (C2022), sowie {PRO_ORG} (P2022).

Siehe auch: {SIMILAR_WORDS}"""

# %%
idx = compounds.index[compounds['original'] == "klimaanbeter"][0]
compounds['PERS_con'].iloc[idx] == pd.isna



compounds['PERS_con'].isna().iloc[idx]
# Out:
# True

# %%
compounds.PERS_pro[0]
# Out:
# nan

# %%
compounds[compounds.PERS_pro.isna() == True]
# Out:
#              original        lemma genus  \
# 0     klimaabzockerei   abzockerei     f
# 4          klimaalarm        alarm     m
# 5       klimaalarmist     alarmist     m
# 6        klimaanbeter      anbeter     m
# 7     klimaapokalypse   apokalypse     f
# ..                ...          ...   ...
# 243       klimazipfel       zipfel     m
# 244       klimazirkus       zirkus     m
# 245        klimazunft        zunft     f
# 246        klimazwang        zwang     m
# 247  klimaüberhitzung  überhitzung     f
#
#                                         compound_forms  \
# 0                 [klimaabzockerei, klimaabzockereien]
# 4    [klimaalarms, klimaalarm, klimaalarmen, klimaa...
# 5                     [klimaalarmist, klimaalarmisten]
# 6         [klimaanbeters, klimaanbeter, klimaanbetern]
# 7                  [klimaapokalypse, klimaapokalypsen]
# ..                                                 ...
# 243          [klimazipfeln, klimazipfel, klimazipfels]
# 244  [klimazirkusse, klimazirkus, klimazirkussen, k...
# 245            [klimazunft, klimazünfte, klimazünften]
# 246  [klimazwange, klimazwängen, klimazwangs, klima...
# 247             [klimaüberhitzungen, klimaüberhitzung]
#
#                                          related_words  \
# 0    [Abzocke, Geldschneiderei, Profitmacherei, Beu...
# 4    [Alarm, Notruf, Alarmruf, Warnton, Warnsignal,...
# 5                                                   []
# 6    [Lover, Verehrer, Bewunderer, Liebhaber, Anbeter]
# 7    [Tag des jüngsten Gerichts, Waterloo, Super-GA...
# ..                                                 ...
# 243  [bestes Stück, Zipfel, Schwengel, Stößel, Schn...
# 244  [Herumlärmen, Gelärme, Lärmerei, Rumlärmen, Zi...
# 245  [Gewerbe, Gilde, Innung, Gewerk, Zunft, Amt, B...
# 246  [Erpressung, Nötigung, Bedingung, Auflage, Res...
# 247                                                 []
#
#                                              hypernyms  \
# 0                                  [Zinssatz, Zinsfuß]
# 4    [Gunst, Geneigtheit, Wohlwollen, Gewogenheit, ...
# 5                                                   []
# 6    [Diplomat, diplomatischer Vertreter, Repräsent...
# 7    [Hallu, Hausnummer, Fata Morgana, Geisterbild,...
# ..                                                 ...
# 243                                                 []
# 244                             [vorweisen, vorzeigen]
# 245  [Arbeitsgemeinschaft, Arbeitskreis, Arbeitsgru...
# 246    [Befehlssatz, Befehlsvorrat, Befehlsrepertoire]
# 247                                                 []
#
#                                           en_hypernyms      concept  \
# 0    [robbery, stealing, thieving, theft, larceny, ...       action
# 4    [fear, fearfulness, fright, emotion, feeling, ...  abstraction
# 5                                                  NaN       person
# 6    [follower, soul, person, someone, mortal, indi...       person
# 7    [state, attribute, abstraction, abstract entit...  abstraction
# ..                                                 ...          ...
# 243  [cylinder, round shape, form, shape, attribute...  abstraction
# 244  [bowl, sports stadium, stadium, arena, constru...       person
# 245                                                 []  abstraction
# 246  [regulating, regulation, control, activity, hu...       action
# 247                                                NaN  abstraction
#
#                                             definition  \
# 0                               [der Akt des Stehlens]
# 4    [Angst, die sich aus dem Bewusstsein einer Gef...
# 5                                                   []
# 6       [ein leidenschaftlicher Anhänger und Verehrer]
# 7    [Visionäre Beschreibung eines Zustandes, in de...
# ..                                                 ...
# 243                     [eine hohle zylindrische Form]
# 244  [(in der Antike) ein Freiluftstadion für Wagen...
# 245  [None, die Handlungen und Tätigkeiten, die ein...
# 246  [der Akt, etwas einzuränken, der Vorgang, dass...
# 247                                                 []
#
#                                          similar_words PERS_pro  \
# 0                                                   []      NaN
# 4                   [alarm, alarmist, alarm, alarmist]      NaN
# 5                   [alarm, alarmist, alarmist, alarm]      NaN
# 6                                          [sektierer]      NaN
# 7    [armageddon, untergang, apokalypse, apokalypti...      NaN
# ..                                                 ...      ...
# 243                                                 []      NaN
# 244                                   [kabarett, show]      NaN
# 245                                                 []      NaN
# 246                                                 []      NaN
# 247                                                 []      NaN
#
#                                               PERS_con ORG_pro  \
# 0                               {'Werner Kirstein': 1}     NaN
# 4    {'Sterling Burnett': 6, 'Donald Trump': 1, 'Ju...     NaN
# 5    {'Sterling Burnett': 6, 'Donald Trump': 1, 'Ha...     NaN
# 6                                                  NaN     NaN
# 7    {'Donald Trump': 2, 'Harald Kunstmann': 1, 'St...     NaN
# ..                                                 ...     ...
# 243                                {'Donald Trump': 1}     NaN
# 244  {'Angela Merkel': 1, 'Ulli Kulke': 1, 'Hans Jo...     NaN
# 245                   {'Hans Joachim Schellnhuber': 1}     NaN
# 246                                                NaN     NaN
# 247                                                NaN     NaN
#
#                                                ORG_con manual_sentiment  \
# 0                                                  NaN         negative
# 4    {'UN': 5, 'Heartland Institute': 10, 'IPCC': 2...         negative
# 5    {'UN': 3, 'Heartland Institute': 7, 'IPCC': 18...         negative
# 6                                          {'EIKE': 1}          neutral
# 7    {'WUWT': 1, 'Die Grünen': 2, 'BR': 1, 'Bayeris...         negative
# ..                                                 ...              ...
# 243                                                NaN          neutral
# 244                                 {'Wett Online': 1}          neutral
# 245                                                NaN          neutral
# 246                                                NaN          neutral
# 247                                  {'Die Grünen': 3}         negative
#
#      tf_pro  tf_con  tfidf_pro  tfidf_con
# 0         0       1        NaN   0.000000
# 4         0      38        NaN   0.305785
# 5         0     115        NaN   0.942149
# 6         0       1        NaN   0.000000
# 7         0       9        NaN   0.066116
# ..      ...     ...        ...        ...
# 243       0       1        NaN   0.000000
# 244       0       6        NaN   0.041322
# 245       0       1        NaN   0.000000
# 246       0       1        NaN   0.000000
# 247       0       3        NaN   0.016529
#
# [211 rows x 19 columns]

# %%
#def fill_persons(df):
    
for word in compounds.original[:15]:
    #print(compound)
    idx = compounds.index[compounds['original'] == word][0]
    
    if compounds['concept'].iloc[idx] == "person":
        #print(compound)
        
        text = """Der Begriff {COMPOUND} bezeichnet eine/n {DEFINITION} im Bezug auf den Klimawandel.\nDer Begriff wird in unserem Korpus {CON_FREQ} Mal von den Klimaskeptikern und {PRO_FREQ} Mal von den Klimaaktivisten verwendetund ist {SENTIMENT} konnotiert. """
        
        # retrieve according information
        compound = word.capitalize()
        con_freq = compounds['tf_con'].iloc[idx]
        pro_freq = compounds['tf_pro'].iloc[idx]
        sentiment = compounds['manual_sentiment'].iloc[idx]
        
        try:
            definition = compounds['definition'].iloc[idx][0] # try [0] for definition
        except:
            definition = " "
            
        
        # retrieve number of persons. if 0 then do nothing
        
        # if we have at least one person in PERS_con
        if compounds['PERS_con'].isna().iloc[idx] == False:
            try:
                con_pers =  " und ".join([el[0] for el in compounds['PERS_con'].iloc[idx].most_common(2)])
                text += """\nPersonen, die im Zusammenhang mit dem Begriff erwähnt werden sind 
                            {CON_PERS} (Con Corpus) """
            except:
                con_pers = compounds['PERS_con'].iloc[idx].most_common(1)[0]
                text += """\nPersonen, die im Zusammenhang mit dem Begriff erwähnt werden sind {CON_PERS} (Con Corpus) """
                
        else:
            print("NO PERSON FOUND")
            con_pers = " " 
            
        # if we have at least one person in PERS_con
        if compounds['PERS_pro'].isna().iloc[idx] == False:
            try:
                print("2 PERSONS FOUND")
                pro_pers = " und ".join([el[0] for el in compounds['PERS_pro'].iloc[idx].most_common(2)])
                text +=  """und {PRO_PERS} (Pro Corpus). """
            except:
                print("ONLY 1 PERSON FOUND")
                pro_pers = compounds['PERS_pro'].iloc[idx].most_common(1)[0]
                text +=  """und {PRO_PERS} (Pro Corpus). """
        else:
            con_pers = " "
            
        if compounds['ORG_con'].isna().iloc[idx] == False:
            try:
                con_org =  ", ".join([el[0] for el in compounds['ORG_con'].iloc[idx].most_common(2)])
                text +=  """\nAußerdem werden im Kontext von {COMPOUND} folgende Organisationen genannt: {CON_ORG} (C2022). """
            except:
                con_org = compounds['ORG_con'].iloc[idx].most_common(1)[0]
                text +=  """\nAußerdem werden im Kontext von {COMPOUND} folgende Organisationen genannt: {CON_ORG} (C2022). """
                
        else:
            con_org = " " 
            
        # if we have at least one person in PERS_con
        if compounds['ORG_pro'].isna().iloc[idx] == False:
            try:
                pro_org =  ", ".join([el[0] for el in compounds['ORG_pro'].iloc[idx].most_common(2)])
                text +=  """und {PRO_ORG} (P2022). """
            except:
                pro_org = compounds['ORG_pro'].iloc[idx].most_common(1)[0]
                text +=  """und {PRO_ORG} (P2022). """    
        else:
            pro_org = " "  
            
        if len(compounds['similar_words'].iloc[idx]) != 0:
            #print(len(compounds['similar_words'].iloc[idx]))
            similar_words = ", ".join(compounds['similar_words'].iloc[idx])
            text += """\nSiehe auch: {SIMILAR_WORDS}"""
        else:
            print("NO SIMILAR WORDS")
            
        full_definition = text.format(COMPOUND= compound, DEFINITION= definition, CON_FREQ= con_freq,
                        PRO_FREQ = pro_freq, SENTIMENT= sentiment, CON_PERS = con_pers, PRO_PERS = pro_pers, 
                        CON_ORG = con_org, PRO_ORG = pro_org, SIMILAR_WORDS= similar_words)
        
        
       # full_definition = persons_text.format(COMPOUND= compound, DEFINITION= definition, CON_FREQ= con_freq,
        #                 PRO_FREQ = pro_freq, SENTIMENT= sentiment, CON_PERS = con_pers, PRO_PERS = pro_pers, 
         #                CON_ORG = con_org, PRO_ORG = pro_org, SIMILAR_WORDS= similar_words)
        
        print(full_definition)
        print("_"*50)
                
        # save to column "full_definition"
# Out:
# 2 PERSONS FOUND
# Der Begriff Klimaaktivist bezeichnet eine/n ein militanter Reformer im Bezug auf den Klimawandel.
# Der Begriff wird in unserem Korpus 66 Mal von den Klimaskeptikern und 61 Mal von den Klimaaktivisten verwendetund ist positive konnotiert.
# Personen, die im Zusammenhang mit dem Begriff erwähnt werden sind
#                             Greta Thunberg und Bill McKibben (Con Corpus) und Greta Thunberg und Vanessa Nakate (Pro Corpus).
# Außerdem werden im Kontext von Klimaaktivist folgende Organisationen genannt: EIKE, IPCC (C2022). und FFF, EU (P2022).
# Siehe auch: demagoge, macher, aktivist, aktivismus
# __________________________________________________
# 2 PERSONS FOUND
# Der Begriff Klimaaktivistin bezeichnet eine/n   im Bezug auf den Klimawandel.
# Der Begriff wird in unserem Korpus 9 Mal von den Klimaskeptikern und 24 Mal von den Klimaaktivisten verwendetund ist positive konnotiert.
# Personen, die im Zusammenhang mit dem Begriff erwähnt werden sind
#                             Greta Thunberg und Naomi Seibt (Con Corpus) und Greta Thunberg und Howey Ou (Pro Corpus).
# Außerdem werden im Kontext von Klimaaktivistin folgende Organisationen genannt: New York Post, EIKE (C2022). und FFF, EU (P2022).
# Siehe auch: aktivistin, aktivist
# __________________________________________________
# Der Begriff Klimaalarmist bezeichnet eine/n   im Bezug auf den Klimawandel.
# Der Begriff wird in unserem Korpus 115 Mal von den Klimaskeptikern und 0 Mal von den Klimaaktivisten verwendetund ist negative konnotiert.
# Personen, die im Zusammenhang mit dem Begriff erwähnt werden sind
#                               (Con Corpus)
# Außerdem werden im Kontext von Klimaalarmist folgende Organisationen genannt: IPCC, EIKE (C2022).
# Siehe auch: alarm, alarmist, alarmist, alarm
# __________________________________________________
# NO PERSON FOUND
# Der Begriff Klimaanbeter bezeichnet eine/n ein leidenschaftlicher Anhänger und Verehrer im Bezug auf den Klimawandel.
# Der Begriff wird in unserem Korpus 1 Mal von den Klimaskeptikern und 0 Mal von den Klimaaktivisten verwendetund ist neutral konnotiert.
# Außerdem werden im Kontext von Klimaanbeter folgende Organisationen genannt: EIKE (C2022).
# Siehe auch: sektierer
# __________________________________________________
# NO PERSON FOUND
# Der Begriff Klimaapokalyptiker bezeichnet eine/n   im Bezug auf den Klimawandel.
# Der Begriff wird in unserem Korpus 1 Mal von den Klimaskeptikern und 0 Mal von den Klimaaktivisten verwendetund ist negative konnotiert.
# Siehe auch: apokalyptiker, apokalypse
# __________________________________________________
# NO SIMILAR WORDS
# Der Begriff Klimaapostel bezeichnet eine/n (Neues Testament) einer der ursprünglichen 12 Jünger, die von Christus ausgewählt wurden, um sein Evangelium zu verkünden im Bezug auf den Klimawandel.
# Der Begriff wird in unserem Korpus 3 Mal von den Klimaskeptikern und 0 Mal von den Klimaaktivisten verwendetund ist neutral konnotiert.
# Personen, die im Zusammenhang mit dem Begriff erwähnt werden sind
#                               (Con Corpus)
# Außerdem werden im Kontext von Klimaapostel folgende Organisationen genannt: EIKE, Spiegel (C2022).
# __________________________________________________

# %%
text = '{0} BLAH BLAH {1} BLAH {2} BLAH BLIH BLEH'
lists = ['Klimaleugner', 'Greta', 'Stefan']
print(text.format(0 = "YAY", 1 = *lists, 2 = "NAY"))
# Out:
#   File "/var/folders/bx/q0xtplm10vxb6sm32kbzrbh00000gn/T/ipykernel_50682/2663628612.py", line 3
#     print(text.format(0 = "YAY", 1 = *lists, 2 = "NAY"))
#                       ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
#', '.join(['%.2f']*len(x))

l1 = ['Klimaleugner', 'Greta', 'Stefan']

", ".join(l1)
# Out:
# 'Klimaleugner, Greta, Stefan'

# %%
#def fill_persons(df):
    
for word in compounds.original[:15]:
    #print(compound)
    idx = compounds.index[compounds['original'] == word][0]
    
    if compounds['concept'].iloc[idx] == "person":
        #print(compound)
        #filler = []
        text = """Der Begriff {COMPOUND} bezeichnet eine/n {DEFINITION} im Bezug auf den Klimawandel.\nDer Begriff wird in unserem Korpus {CON_FREQ} Mal von den Klimaskeptikern und {PRO_FREQ} Mal von den Klimaaktivisten verwendetund ist {SENTIMENT} konnotiert. """
        
        #filler
        # retrieve according information
        compound = word.capitalize()
        con_freq = compounds['tf_con'].iloc[idx]
        pro_freq = compounds['tf_pro'].iloc[idx]
        sentiment = compounds['manual_sentiment'].iloc[idx]
        
        try:
            definition = compounds['definition'].iloc[idx][0] # try [0] for definition
        except:
            definition = " "
            
        
        # retrieve number of persons. if 0 then do nothing
        
        # if we have at least one person in PERS_con
        if compounds['PERS_con'].isna().iloc[idx] == False:
            try:
                con_pers =  ", ".join([el[0] for el in compounds['PERS_con'].iloc[idx].most_common(2)])
                text += """\nPersonen, die im Zusammenhang mit dem Begriff erwähnt werden sind 
                            {CON_PERS} (Con Corpus) """
            except:
                con_pers = compounds['PERS_con'].iloc[idx].most_common(1)[0]
                text += """\nPersonen, die im Zusammenhang mit dem Begriff erwähnt werden sind {CON_PERS} (Con Corpus) """
                
        else:
            print("NO PERSON FOUND")
            con_pers = " " 
            
        # if we have at least one person in PERS_con
        if compounds['PERS_pro'].isna().iloc[idx] == False:
            try:
                print("2 PERSONS FOUND")
                pro_pers = [el[0] for el in compounds['PERS_pro'].iloc[idx].most_common(2)]
                text +=  """und {PRO_PERS} (Pro Corpus). """
            except:
                print("ONLY 1 PERSON FOUND")
                pro_pers = compounds['PERS_pro'].iloc[idx].most_common(1)[0]
                text +=  """und {PRO_PERS} (Pro Corpus). """
        else:
            con_pers = " "
            
        if compounds['ORG_con'].isna().iloc[idx] == False:
            try:
                con_org =  [el[0] for el in compounds['ORG_con'].iloc[idx].most_common(2)]
                text +=  """\nAußerdem werden im Kontext von {COMPOUND} folgende Organisationen genannt: {CON_ORG} (C2022). """
            except:
                con_org = compounds['ORG_con'].iloc[idx].most_common(1)[0]
                text +=  """\nAußerdem werden im Kontext von {COMPOUND} folgende Organisationen genannt: {CON_ORG} (C2022). """
                
        else:
            con_org = " " 
            
        # if we have at least one person in PERS_con
        if compounds['ORG_pro'].isna().iloc[idx] == False:
            try:
                pro_org =  [el[0] for el in compounds['ORG_pro'].iloc[idx].most_common(2)]
                text +=  """und {PRO_ORG} (P2022). """
            except:
                pro_org = compounds['ORG_pro'].iloc[idx].most_common(1)[0]
                text +=  """und {PRO_ORG} (P2022). """    
        else:
            pro_org = " "  
            
        if len(compounds['similar_words'].iloc[idx]) != 0:
            #print(len(compounds['similar_words'].iloc[idx]))
            similar_words = compounds['similar_words'].iloc[idx]
            text += """\nSiehe auch: {SIMILAR_WORDS}"""
        else:
            print("NO SIMILAR WORDS")
            
        full_definition = text.format(COMPOUND= compound, DEFINITION= definition, CON_FREQ= con_freq,
                        PRO_FREQ = pro_freq, SENTIMENT= sentiment, CON_PERS = con_pers, PRO_PERS = pro_pers, 
                        CON_ORG = con_org, PRO_ORG = pro_org, SIMILAR_WORDS= similar_words)
        
        
       # full_definition = persons_text.format(COMPOUND= compound, DEFINITION= definition, CON_FREQ= con_freq,
        #                 PRO_FREQ = pro_freq, SENTIMENT= sentiment, CON_PERS = con_pers, PRO_PERS = pro_pers, 
         #                CON_ORG = con_org, PRO_ORG = pro_org, SIMILAR_WORDS= similar_words)
        
        print(full_definition)
        print("_"*50)
                
        # save to column "full_definition"
# Out:
# 2 PERSONS FOUND
# Der Begriff Klimaaktivist bezeichnet eine/n ein militanter Reformer im Bezug auf den Klimawandel.
# Der Begriff wird in unserem Korpus 66 Mal von den Klimaskeptikern und 61 Mal von den Klimaaktivisten verwendetund ist positive konnotiert.
# Personen, die im Zusammenhang mit dem Begriff erwähnt werden sind
#                             Greta Thunberg, Bill McKibben (Con Corpus) und ['Greta Thunberg', 'Vanessa Nakate'] (Pro Corpus).
# Außerdem werden im Kontext von Klimaaktivist folgende Organisationen genannt: ['EIKE', 'IPCC'] (C2022). und ['FFF', 'EU'] (P2022).
# Siehe auch: ['demagoge', 'macher', 'aktivist', 'aktivismus']
# __________________________________________________
# 2 PERSONS FOUND
# Der Begriff Klimaaktivistin bezeichnet eine/n   im Bezug auf den Klimawandel.
# Der Begriff wird in unserem Korpus 9 Mal von den Klimaskeptikern und 24 Mal von den Klimaaktivisten verwendetund ist positive konnotiert.
# Personen, die im Zusammenhang mit dem Begriff erwähnt werden sind
#                             Greta Thunberg, Naomi Seibt (Con Corpus) und ['Greta Thunberg', 'Howey Ou'] (Pro Corpus).
# Außerdem werden im Kontext von Klimaaktivistin folgende Organisationen genannt: ['New York Post', 'EIKE'] (C2022). und ['FFF', 'EU'] (P2022).
# Siehe auch: ['aktivistin', 'aktivist']
# __________________________________________________
# Der Begriff Klimaalarmist bezeichnet eine/n   im Bezug auf den Klimawandel.
# Der Begriff wird in unserem Korpus 115 Mal von den Klimaskeptikern und 0 Mal von den Klimaaktivisten verwendetund ist negative konnotiert.
# Personen, die im Zusammenhang mit dem Begriff erwähnt werden sind
#                               (Con Corpus)
# Außerdem werden im Kontext von Klimaalarmist folgende Organisationen genannt: ['IPCC', 'EIKE'] (C2022).
# Siehe auch: ['alarm', 'alarmist', 'alarmist', 'alarm']
# __________________________________________________
# NO PERSON FOUND
# Der Begriff Klimaanbeter bezeichnet eine/n ein leidenschaftlicher Anhänger und Verehrer im Bezug auf den Klimawandel.
# Der Begriff wird in unserem Korpus 1 Mal von den Klimaskeptikern und 0 Mal von den Klimaaktivisten verwendetund ist neutral konnotiert.
# Außerdem werden im Kontext von Klimaanbeter folgende Organisationen genannt: ['EIKE'] (C2022).
# Siehe auch: ['sektierer']
# __________________________________________________
# NO PERSON FOUND
# Der Begriff Klimaapokalyptiker bezeichnet eine/n   im Bezug auf den Klimawandel.
# Der Begriff wird in unserem Korpus 1 Mal von den Klimaskeptikern und 0 Mal von den Klimaaktivisten verwendetund ist negative konnotiert.
# Siehe auch: ['apokalyptiker', 'apokalypse']
# __________________________________________________
# NO SIMILAR WORDS
# Der Begriff Klimaapostel bezeichnet eine/n (Neues Testament) einer der ursprünglichen 12 Jünger, die von Christus ausgewählt wurden, um sein Evangelium zu verkünden im Bezug auf den Klimawandel.
# Der Begriff wird in unserem Korpus 3 Mal von den Klimaskeptikern und 0 Mal von den Klimaaktivisten verwendetund ist neutral konnotiert.
# Personen, die im Zusammenhang mit dem Begriff erwähnt werden sind
#                               (Con Corpus)
# Außerdem werden im Kontext von Klimaapostel folgende Organisationen genannt: ['EIKE', 'Spiegel'] (C2022).
# __________________________________________________
